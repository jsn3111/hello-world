# %% [markdown]
# <a href="https://colab.research.google.com/github/jsn3111/hello-world/blob/master/%EC%8B%A0%EA%B2%BD%EB%A7%9D%ED%95%A8%EC%88%98%EC%83%9D%EC%84%B1%EC%82%AC%EC%9A%A9125_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0])
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10., 13.])

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='sgd', loss='mean_squared_error')

model.fit(xs, ys, epochs=500)

p = model.predict([12.0])

print('p : ', p)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 264ms/step - loss: 104.1256
# Epoch 2/500
# 1/1 [==============================] - 0s 12ms/step - loss: 81.9321
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 64.4711
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 50.7333
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 39.9249
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 31.4212
# Epoch 7/500
# 1/1 [==============================] - 0s 14ms/step - loss: 24.7306
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 19.4666
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 15.3250
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 12.0663
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 9.5024
# Epoch 12/500
# ...

# %%
xs = [-1., 0., 1., 2., 3., 4.]
ys = [-2., 1., 4., 7., 10., 13.]
w = 10.
b = 10.

y = xs[0]*w + 1*b
print('x = %6.3f, y = %6.3f' %(xs[0], y))

t = ys[0]
E = (y-t)**2/2
print('E = %.7f' %E)

yb = y - t
wb = yb*xs[0]
bb = yb*1
print('wb = %6.3f, bb = %6.3f' %(wb, bb))

lr = 0.01
w = w - lr*wb
b = b - lr*bb
print('w = %6.3f, b = %6.3f' %(w, b))
# Out:
# x = -1.000, y =  0.000
# E = 2.0000000
# wb = -2.000, bb =  2.000
# w = 10.020, b =  9.980

# %%
xs = [-1., 0., 1., 2., 3., 4.]
ys = [-2., 1., 4., 7., 10., 13.]
w = -100.
b = 200.

for epoch in range(2000):
  for n in range(6):
    y = xs[n]*w + 1*b
    # print('x = %6.3f, y = %6.3f' %(xs[0], y))

    t = ys[n]
    E = (y-t)**2/2
    # print('E = %.7f' %E)

    yb = y - t
    wb = yb*xs[n]
    bb = yb*1
    # print('wb = %6.3f, bb = %6.3f' %(wb, bb))

    lr = 0.01
    w = w - lr*wb
    b = b - lr*bb
    if epoch%200==1 and n==0:
      print('w = %6.3f, b = %6.3f' %(w, b))

    # print("="*27)
# Out:
# w = -83.789, b = 194.356
# w =  2.884, b =  1.385
# w =  3.000, b =  1.001
# w =  3.000, b =  1.000
# w =  3.000, b =  1.000
# w =  3.000, b =  1.000
# w =  3.000, b =  1.000
# w =  3.000, b =  1.000
# w =  3.000, b =  1.000
# w =  3.000, b =  1.000

# %%
x1, x2 = 2, 3
t = 27
w1 = 3
w2 = 4
b = 1

for epoch in range(2000):
  print("epoch = %d" %epoch)
  y = x1*w1 + x2*w2 + 1*b
  print("y = %6.3f" %y)

  E = (y-t)**2/2
  print("E = %.7f" %E)
  if E < 0.0000001:
    break

  yb = y - t
  x1b, x2b = yb*w1, yb*w2
  w1b, w2b = yb*x1, yb*x2
  bb = yb*1
  print("x1b, x2b = %6.3f, %6.3f" %(x1b, x2b))
  print("w1b, w2b, bb = %6.3f, %6.3f, %6.3f" %(w1b, w2b, bb))

  lr = 0.01
  w1 = w1 - lr*w1b
  w2 = w2 - lr*w2b
  b = b - lr*bb
  print("w1, w2, b = %6.3f, %6.3f, %6.3f" %(w1, w2, b))
# Out:
# epoch = 0
# y = 19.000
# E = 32.0000000
# x1b, x2b = -24.000, -32.000
# w1b, w2b, bb = -16.000, -24.000, -8.000
# w1, w2, b =  3.160,  4.240,  1.080
# epoch = 1
# y = 20.120
# E = 23.6672000
# x1b, x2b = -21.741, -29.171
# w1b, w2b, bb = -13.760, -20.640, -6.880
# w1, w2, b =  3.298,  4.446,  1.149
# epoch = 2
# y = 21.083
# E = 17.5042611
# x1b, x2b = -19.511, -26.308
# w1b, w2b, bb = -11.834, -17.750, -5.917
# w1, w2, b =  3.416,  4.624,  1.208
# epoch = 3
# y = 21.912
# E = 12.9461515
# x1b, x2b = -17.382, -23.528
# w1b, w2b, bb = -10.177, -15.265, -5.088
# w1, w2, b =  3.518,  4.777,  1.259
# epoch = 4
# y = 22.624
# E = 9.5749737
# x1b, x2b = -15.394, -20.903
# w1b, w2b, bb = -8.752, -13.128, -4.376
# w1, w2, b =  3.605,  4.908,  1.303
# epoch = 5
# y = 23.237
# E = 7.0816505
# x1b, x2b = -13.568, -18.470
# w1b, w2b, bb = -7.527, -11.290, -3.763
# w1, w2, b =  3.680,  5.021,  1.340
# epoch = 6
# y = 23.763
# E = 5.2375887
# x1b, x2b = -11.912, -16.250
# ...
